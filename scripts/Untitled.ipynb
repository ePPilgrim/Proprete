# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("prices.csv")

# %%
df.head(100)
# Out:
#                        Čistící prostředky  Unnamed: 1  Unnamed: 2      Cena
# 0                          Domestos 750ml         NaN         NaN   23.30 Kč
# 1                     Savo koupelna 500ml         NaN         NaN   31.60 Kč
# 2                       Savo kuchyň 500ml         NaN         NaN   31.60 Kč
# 3                      Savo original 1,2l         NaN         NaN   27.50 Kč
# 4                        Savo original 2l         NaN         NaN   39.20 Kč
# ..                                    ...         ...         ...        ...
# 95                             Tyč k mopu         NaN         NaN   89.00 Kč
# 96     Návlek mopu 40cm jazykový bavlněný         NaN         NaN  105.00 Kč
# 97  Návlek mopu 40cm jazykový mikrovlákno         NaN         NaN  105.70 Kč
# 98      Návlek mopu 40cm kapsový bavlněný         NaN         NaN  109.90 Kč
# 99   Návlek mopu 40cm kapsový mikrovlákno         NaN         NaN  104.90 Kč
#
# [100 rows x 4 columns]
